# %% [markdown]
# # BYTE PAIR ENCODING

# %%
import importlib
import tiktoken

# %%
print('tiktoken version: ', importlib.metadata.version('tiktoken'))
# Out:
# tiktoken version:  0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea ? <|endoftext|> In the sunlight terraces "
    "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print("Encoded integers:", integers)
# Out:
# Encoded integers: [15496, 11, 466, 345, 588, 8887, 5633, 220, 50256, 554, 262, 19606, 8812, 2114, 286, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)

print("Decoded strings:", strings)
# Out:
# Decoded strings: Hello, do you like tea ? <|endoftext|> In the sunlight terraces of someunknownPlace.

# %% [markdown]
# ## BYTE PAIR ENCODING

# %% [markdown]
# ### Lets us take another simple example to illustrate how the BPE tokenizer deals with unknown

# %%
integers = tokenizer.encode('Akwirw ier')
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier
